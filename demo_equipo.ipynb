# %% [markdown]
# # Describe la ejecución paso a paso de todos los métodos de tu clase

# %% [markdown]
# xxxx

# %% [markdown]
# # Incluye el promt usado en tu clase de acuerdo con las instrucciones dadas

# %% [markdown]
# xxxx
